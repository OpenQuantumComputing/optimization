# %%
#run: pip install openquantumcomputing
from openquantumcomputing.QAOAMaxCut import QAOAMaxCut

# %%
from qiskit import *
import numpy as np
import networkx as nx

import matplotlib.pyplot as pl
from mpl_toolkits.axes_grid1 import make_axes_locatable
from qiskit.visualization import *

# %%
numV=26
G = nx.read_gml("../../data/sample_graphs/w_ba_n"+str(numV)+"_k4_0.gml")
pos = nx.spring_layout(G)
nx.draw_networkx(G,pos=pos)

# %%
params={'G': G}
qaoamc = QAOAMaxCut()

# %%
qasm_sim = Aer.get_backend('qasm_simulator')

# %%
qaoamc.sample_cost_landscape(qasm_sim, 1024, params=params, angles={"gamma": [0,np.pi/2,10], "beta": [0,np.pi,20]})
# Out:
# Calculating Energy landscape for depth p=1...
# Calculating Energy landscape done

# %%
f = pl.figure(figsize=(6, 6), dpi= 80, facecolor='w', edgecolor='k');
_=pl.xlabel(r'$\gamma$')
_=pl.ylabel(r'$\beta$')
ax = pl.gca()
_=pl.title('Expectation value')
im = ax.imshow(qaoamc.E,interpolation='bicubic',origin='lower',extent=[0,np.pi/2,0,np.pi])
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
_=pl.colorbar(im, cax=cax)

# %%
f = pl.figure(figsize=(6, 6), dpi= 80, facecolor='w', edgecolor='k');
_=pl.xlabel(r'$\gamma$')
_=pl.ylabel(r'$\beta$')
ax = pl.gca()
_=pl.title('Variance')
im = ax.imshow(qaoamc.Var,interpolation='bicubic',origin='lower',extent=[0,np.pi/2,0,np.pi])
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
_=pl.colorbar(im, cax=cax)

# %%
for i in range(3):
    qaoamc.increase_depth(qasm_sim, 1024, params=params)
pl.plot(qaoamc.costval.values(),'o--')
# Out:
# rep= 0 : -25.99862680783751
# rep= 1 : -25.140267018792454
# rep= 2 : -26.189880878209095
# rep= 3 : -24.92521392381546
# rep= 4 : -25.269444039323368
# -26.233962949488145
# [0.52364846 0.33069954]
# rep= 0 : -26.110116885070564
# rep= 1 : -25.65336601877148
# rep= 2 : -25.148869254282214
# rep= 3 : -25.222075551303007
# rep= 4 : -25.36153789717365
# -26.18607637748823
# [0.69018935 0.18478676 0.52361999 0.16081284]
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#       1 for i in range(3):
# ----> 2     qaoamc.increase_depth(qasm_sim, 1024, params=params)
#       3 pl.plot(qaoamc.costval.values(),'o--')
#
# File ~/OpenQuantumComputing/OpenQuantumComputing/openquantumcomputing/QAOABase.py:272, in QAOABase.increase_depth(self, backend, shots, noisemodel, params, method)
#     270     angles0 = self.random_init(gamma_bounds, beta_bounds, self.current_depth+1)
#     271 #cons = self.COBYLAConstraints_MaxCut(gamma_bounds, beta_bounds, depth)
# --> 272 res = self.local_opt(angles0, backend, shots, noisemodel=noisemodel, params=params, method=method)
#     273 print("rep=",rep, ":", res.fun)
#     274 #if best_res is None:
#     275 #    best_res = res
#     276 #else:
#     277 #    if res.fun<best_res.fun:
#     278 #        best_res=res
#
# File ~/OpenQuantumComputing/OpenQuantumComputing/openquantumcomputing/QAOABase.py:237, in QAOABase.local_opt(self, angles0, backend, shots, noisemodel, params, method)
#     231 depth=int(len(angles0)/2)
#     233 #gamma_bounds=(0,np.pi)
#     234 #beta_bounds=(0,np.pi)
#     235 #cons = self.COBYLAConstraints_MaxCut(gamma_bounds, beta_bounds, depth)
# --> 237 res = minimize(self.loss, x0 = angles0, method = method,
#     238                args=(backend, depth, shots, noisemodel, params))
#     239 return res
#
# File ~/anaconda3/envs/oqc/lib/python3.10/site-packages/scipy/optimize/_minimize.py:629, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#     628 elif meth == 'cobyla':
# --> 629     return _minimize_cobyla(fun, x0, args, constraints, **options)
#     630 elif meth == 'slsqp':
#     631     return _minimize_slsqp(fun, x0, args, jac, bounds,
#     632                            constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/oqc/lib/python3.10/site-packages/scipy/optimize/cobyla.py:34, in synchronized.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(func)
#      32 def wrapper(*args, **kwargs):
#      33     with _module_lock:
# ---> 34         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/oqc/lib/python3.10/site-packages/scipy/optimize/cobyla.py:260, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, **unknown_options)
#     257     return f
#     259 info = np.zeros(4, np.float64)
# --> 260 xopt, info = _cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     261                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     262                               dinfo=info)
#     264 if info[3] > catol:
#     265     # Check constraint violation
#     266     info[0] = 4
#
# File ~/anaconda3/envs/oqc/lib/python3.10/site-packages/scipy/optimize/cobyla.py:252, in _minimize_cobyla.<locals>.calcfc(x, con)
#     251 def calcfc(x, con):
# --> 252     f = fun(np.copy(x), *args)
#     253     i = 0
#     254     for size, c in izip(cons_lengths, constraints):
#
# File ~/OpenQuantumComputing/OpenQuantumComputing/openquantumcomputing/QAOABase.py:67, in QAOABase.loss(self, angles, backend, depth, shots, noisemodel, params)
#      64 else:
#      65     job = start_or_retrieve_job(name+"_"+str(opt_iterations), backend, circuit, options={'shots' : shots})
# ---> 67 e,v = self.measurementStatistics(job, params=params)
#      69 self.g_values[str(self.g_it)] = -e
#      70 self.g_angles[str(self.g_it)] = angles
#
# File ~/OpenQuantumComputing/OpenQuantumComputing/openquantumcomputing/QAOABase.py:83, in QAOABase.measurementStatistics(self, job, params)
#      76 def measurementStatistics(self, job, params):
#      77     """
#      78     implements a function for expectation value and variance
#      79
#      80     :param job: job instance derived from BaseJob
#      81     :return: expectation and variance
#      82     """
# ---> 83     jres=job.result()
#      84     counts_list=jres.get_counts()
#      85     if isinstance(counts_list, list):
#
# File ~/anaconda3/envs/oqc/lib/python3.10/site-packages/qiskit/providers/aer/jobs/utils.py:41, in requires_submit.<locals>._wrapper(self, *args, **kwargs)
#      39 if self._future is None:
#      40     raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 41 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/oqc/lib/python3.10/site-packages/qiskit/providers/aer/jobs/aerjob.py:78, in AerJob.result(self, timeout)
#      60 @requires_submit
#      61 def result(self, timeout=None):
#      62     # pylint: disable=arguments-differ
#      63     """Get job result. The behavior is the same as the underlying
#      64     concurrent Future objects,
#      65
#    (...)
#      76         concurrent.futures.CancelledError: if job cancelled before completed.
#      77     """
# ---> 78     return self._future.result(timeout=timeout)
#
# File ~/anaconda3/envs/oqc/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/anaconda3/envs/oqc/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
